# %% [markdown]
# <a href="https://colab.research.google.com/github/MihaelaHudisteanu/PMP-2024/blob/main/Lab09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pymc as pm
import arviz as az
import matplotlib.pyplot as plt

Y_values = [0, 5, 10]
theta_values = [0.2, 0.5]

for Y in Y_values:
    for theta in theta_values:
        with pm.Model() as model:
            n = pm.Poisson('n', mu=10)
            Y_obs = pm.Binomial('Y_obs', n=n, p=theta, observed=Y)
            idata = pm.sample(1000, random_seed=123,return_inferencedata=True)

        az.plot_posterior(idata, var_names=['n'], hdi_prob=0.95)
        plt.title(f'Posterior pentru Y={Y}, theta={theta}')
        plt.show()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ...

# %% [markdown]
# b)
#
# Daca il micsoram pe theta si Y e fix, n creste (adica sunt exact Y produse cumparate, dar probabilitatea ca un client sa cumpere produsul scade, deci sunt mai multi clienti)
#
# Daca il marim pe Y si theta e fix, n creste (adica probabilitatea ca un client sa cumpere produsul e acceasi, dar sunt mai multe produse cumparate, deci sunt mai multi clienti)
